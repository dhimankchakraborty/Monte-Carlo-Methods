# %%
import numpy as np
import matplotlib.pyplot as plt
from functions import *

# %%
x_arr = np.linspace(0, 5, 101)
print(x_arr)
# Out:
# [0.   0.05 0.1  0.15 0.2  0.25 0.3  0.35 0.4  0.45 0.5  0.55 0.6  0.65
#  0.7  0.75 0.8  0.85 0.9  0.95 1.   1.05 1.1  1.15 1.2  1.25 1.3  1.35
#  1.4  1.45 1.5  1.55 1.6  1.65 1.7  1.75 1.8  1.85 1.9  1.95 2.   2.05
#  2.1  2.15 2.2  2.25 2.3  2.35 2.4  2.45 2.5  2.55 2.6  2.65 2.7  2.75
#  2.8  2.85 2.9  2.95 3.   3.05 3.1  3.15 3.2  3.25 3.3  3.35 3.4  3.45
#  3.5  3.55 3.6  3.65 3.7  3.75 3.8  3.85 3.9  3.95 4.   4.05 4.1  4.15
#  4.2  4.25 4.3  4.35 4.4  4.45 4.5  4.55 4.6  4.65 4.7  4.75 4.8  4.85
#  4.9  4.95 5.  ]

# %%
y_arr = f_1(x_arr)
print(y_arr)
# Out:
# [  1.           1.0512711    1.10517092   1.16183424   1.22140276
#    1.28402542   1.34985881   1.41906755   1.4918247    1.56831219
#    1.64872127   1.73325302   1.8221188    1.91554083   2.01375271
#    2.11700002   2.22554093   2.33964685   2.45960311   2.58570966
#    2.71828183   2.85765112   3.00416602   3.15819291   3.32011692
#    3.49034296   3.66929667   3.85742553   4.05519997   4.26311452
#    4.48168907   4.71147018   4.95303242   5.20697983   5.47394739
#    5.75460268   6.04964746   6.35981952   6.68589444   7.02868758
#    7.3890561    7.76790111   8.16616991   8.5848584    9.0250135
#    9.48773584   9.97418245  10.48556972  11.02317638  11.58834672
#   12.18249396  12.80710378  13.46373804  14.15403865  14.87973172
#   15.64263188  16.44464677  17.28778184  18.17414537  19.10595373
#   20.08553692  21.11534442  22.19795128  23.33606458  24.5325302
#   25.79033992  27.11263892  28.50273364  29.96410005  31.50039231
# ...

# %%
plt.plot(x_arr, y_arr)
plt.show()

# %%
upper_limit = 1
lower_limit = 0
monte_carlo_steps = 100_000_000

exact_result = np.exp(1) - np.exp(0)

integration_result, error = crude_mc_integration(f_1, monte_carlo_steps, upper_limit, lower_limit)

print(exact_result)
print(integration_result)
print(exact_result - integration_result)
# print(variance)
print(error)
# Out:
# 1.718281828459045
# 1.7182442800767777
# 3.7548382267438285e-05
# 4.919730553359002e-05

# %%
upper_limit = 1
lower_limit = 0
monte_carlo_steps = 100_000_000

# exact_result = np.exp(1) - np.exp(0)

integration_result, error = crude_mc_integration(f_2, monte_carlo_steps, upper_limit, lower_limit)

print(exact_result)
print(integration_result)
# print(exact_result - integration_result)
# print(variance)
print(error)
# Out:
# 1.718281828459045
# 3.19481576502656
# 0.0001787629244107083
